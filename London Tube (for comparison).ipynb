# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
import pathpy as pp

# %% [markdown]
# # London Tube
# all info at https://github.com/IngoScholtes/csh2018-tutorial/tree/master/data

# %%
tort_tnet = pp.Network.read_file('Data/Tube/tube.edges',separator=';',directed=True)
tort_tnet
# Out:
# 2021-03-25 15:20:59 [Severity.INFO]	Reading edge list ...
# 2021-03-25 15:20:59 [Severity.INFO]	finished.
# <style>
#     text.label_eIZZEHoU {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_eIZZEHoU line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_eIZZEHoU circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="eIZZEHoU">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='eIZZEHoU_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
# ...
