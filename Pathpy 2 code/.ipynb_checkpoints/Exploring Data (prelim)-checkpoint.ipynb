# %%
import os
os.chdir("..")

import networkx as nx
import pandas as pd
import scipy
import numpy as np
import matplotlib.pyplot as plt
import os.path
import pathpy as pp
import my_functions
from my_functions import matprint
import igraph
import csv
from tabulate import tabulate

from IPython.display import * # no idea what this does
from IPython.display import HTML # no idea what this does

# %% [markdown]
# **csh tutorial:** https://ingoscholtes.github.io/pathpy/tutorial.html#data <br>
# **old pathpy repo:** https://github.com/IngoScholtes/pathpy <br>
# **pathpy 3 repo:** https://github.com/pathpy/pathpy <br>
#
# # 1. Flight Data
# Leaving out departure data and focusing on pathway data <br>
# **NOTE:** using subset for now for speed. Fix this in Data Processing notebook once ready.

# %% [markdown]
#     # from departures dataset
#     m1 = pp.Network.read_file("Data/US flights 2011/US flights 2011.edges",directed=True)
#
#     # network statistics
#     print('Network Statistics:')
#     print("number of nodes: {}".format(m1.ncount()))
#     print("number of edges: {}".format(m1.ecount()))
#     # print("total edge weight: {}".format(m1.transition_matrix())) # not what I expected it to do
#
#     print("average clustering coefficient: {}".format(pp.algorithms.statistics.avg_clustering_coefficient(m1)))
#     print("network diameter: {}".format(pp.algorithms.shortest_paths.diameter(m1)))

# %%
# from paths dataset - use this instead
flight_paths = pp.Paths.read_file("Data/US flights 2011/US flights od.ngram", separator=',', frequency=True)
print(flight_paths)
# Out:
# 2021-04-04 18:13:39 [Severity.INFO]	Reading ngram data ...
# 2021-04-04 18:13:39 [Severity.INFO]	finished. Read 358 paths with maximum length 6
# 2021-04-04 18:13:39 [Severity.INFO]	Calculating sub path statistics ...
# 2021-04-04 18:13:39 [Severity.INFO]	finished.
# Total path count: 		18319.0
# [Unique / Sub paths / Total]: 	[358.0 / 83241.0 / 101560.0]
# Nodes:				93
# Edges:				473
# Max. path length:		6
# Avg path length:		1.8010262568917517
# Paths of length k = 0		0.0 [ 0.0 / 51312.0 / 51312.0 ]
# Paths of length k = 1		5524.0 [ 16.0 / 27469.0 / 32993.0 ]
# Paths of length k = 2		11590.0 [ 123.0 / 3084.0 / 14674.0 ]
# Paths of length k = 3		555.0 [ 107.0 / 1324.0 / 1879.0 ]
# Paths of length k = 4		630.0 [ 96.0 / 44.0 / 674.0 ]
# Paths of length k = 5		16.0 [ 15.0 / 8.0 / 24.0 ]
# Paths of length k = 6		4.0 [ 1.0 / 0.0 / 4.0 ]

# %%
# help(pp.visualisation.alluvial)

# %% [markdown]
# ## Time-aggregated network analysis
# Check if the network is sparse, $M \ll M_{max}=\begin{pmatrix} N \\ 2\end{pmatrix}$ Or $M=\mathcal{o}(M_{max})$. So here there are 10 times as many possible edges as edges, is that sparse? <br>
# $f(n) = \mathcal{O}(1)$ if $\frac{f(n)}{c}\to1$ as $n \to \infty$ for any $c$ at all. Of the same order as. <br>
# $f(n) = \mathcal{o}(1)$ if $\frac{f(n)}{c}\to0$ as $n \to \infty$ for any $c$ at all. Ultimately smaller than. <br>
# This isn't really relevent.

# %%
m1 = pp.Network.from_paths(flight_paths)

# network statistics
print('Static Network Statistics:')
print("number of nodes: {}".format(m1.ncount()))
print("maximum possible edges: {}".format(scipy.special.comb(m1.ncount(), 2)))
print("number of edges: {}".format(m1.ecount()))
# print("total edge weight: {}".format(m1.transition_matrix())) # not what I expected it to do

print("average clustering coefficient: {}".format(pp.algorithms.statistics.avg_clustering_coefficient(m1)))
print("network diameter: {}".format(pp.algorithms.shortest_paths.diameter(m1)))
A = m1.adjacency_matrix(weighted=True)
# Adense = A.todense()
# Out:
# Static Network Statistics:
# number of nodes: 93
# maximum possible edges: 4278.0
# number of edges: 473
# average clustering coefficient: 0.44705890333102327
# network diameter: inf

# %% [markdown]
# ## Notes:
# The graph has infinite diameter which means it is disconnected https://mathworld.wolfram.com/GraphDiameter.html . <br>
# **Lecture notes definition:** a set is an ergodic set if it's possible to go from any states $i$ to $j$ within the set and a process doesn't leave the set once it's in it. A state that's not in the ergodic set is called a *transient* state. I should also check there are no nodes with no outgoing links because then the transition probability for the discrete Markov chain $(181)$ will blow up <br>
# So it seems like I'll have to double check a lot of the centrality measures I did on it.

# %%
# degree distribution + histogram
# power law
degrees = m1.degrees()
#indegrees = m1.degrees(degree="indegree")
#outdegrees = m1.degrees(degree="outdegree")
# fixed bin size
bins = np.arange(0, 150, 5)
plt.hist(degrees,density=True,bins=bins,alpha=0.5,color='b',edgecolor="black")
plt.title('Undirected flight network degree distribution')
plt.xlabel('total node degree')
plt.ylabel('count')
plt.show()

# %%
# log-log plot (not cdf) shows not exactly straight line indicating no power law
plt.hist(degrees,density=True,log=True,bins=50,alpha=0.5,color='b',edgecolor="black")
plt.title('Undirected flight network degree loglog-distribution')
plt.xscale('log')
plt.xlabel('total node degree')
plt.ylabel('count')
plt.show()

# %%
# centrality analyses - can use on paths or higher-order networks or paths
# M1 IS NOT ERGODIC => TELEPORTATIONS NEEDED
# node traversals / visitation probabilities for paths
# closeness for higher-order because projects back down
eig_cents = pp.algorithms.centralities.eigenvector(m1)
betw_cents = pp.algorithms.centralities.betweenness(m1)
close_cents = pp.algorithms.centralities.closeness(m1)
pr_cents = pp.algorithms.centralities.pagerank(m1)

# top 10 for each centrality
eig_ranks10 = pp.algorithms.centralities.rank_centralities(eig_cents)[:10]
pr_cents10 = pp.algorithms.centralities.rank_centralities(pr_cents)[:10]
close_cents10 = pp.algorithms.centralities.rank_centralities(close_cents)[:10]
betw_cents10 = pp.algorithms.centralities.rank_centralities(betw_cents)[:10]
# Out:
# 2021-04-03 15:29:14 [Severity.INFO]	Calculating betweenness centralities ...
# 2021-04-03 15:29:14 [Severity.INFO]	Calculating closeness in network ...
# 2021-04-03 15:29:14 [Severity.INFO]	finished.

# %%
# measure the correlation between the centrality measures
cent_vals  = pd.DataFrame(list(eig_cents.values()))
cent_vals.columns = ["eigenvector"]
cent_vals["PageRank"]  = pd.DataFrame(list(pr_cents.values()))
cent_vals["betweenness"]  = pd.DataFrame(list(betw_cents.values()))
cent_vals["closeness"]  = pd.DataFrame(list(close_cents.values()))
cent_vals.index = list(eig_cents.keys())
print("Correlations:")
print(cent_vals.corr(method='pearson'))
cent_vals

# eigenvector and PageRank are pretty highly correlated which is too 
# be expected but betweenness and closeness are both very different
# because they measure quite different aspects of the nodes
# Out:
# Correlations:
#              eigenvector  PageRank  betweenness  closeness
# eigenvector     1.000000  0.865487     0.534371   0.515169
# PageRank        0.865487  1.000000     0.585500   0.352960
# betweenness     0.534371  0.585500     1.000000   0.215879
# closeness       0.515169  0.352960     0.215879   1.000000
#      eigenvector  PageRank  betweenness  closeness
# ABQ     0.008229  0.004891  1089.970655   0.669091
# BUR     0.021477  0.029383  1495.328550   0.888889
# LAX     0.028792  0.082955  2190.391542   0.689139
# OAK     0.022715  0.034725  9833.070837   0.671533
# ONT     0.021328  0.032689  3482.950640   0.741935
# ..           ...       ...          ...        ...
# CRW     0.000854  0.001348     0.000000   0.000000
# VIS     0.000666  0.001206     0.000000   0.000000
# SJT     0.000854  0.001348     0.000000   0.000000
# MBS     0.000900  0.001390     0.000000   0.000000
# EYW     0.000854  0.001348     0.000000   0.000000
#
# [185 rows x 4 columns]

# %%
# print top 10 centralities by each measure
centralities = pd.DataFrame(list(zip(*eig_ranks10))[0])
centralities.columns = ["eigenvector"]
centralities["betweenness"] = list(zip(*betw_cents10))[0]
centralities["closeness"] = list(zip(*close_cents10))[0]
centralities["PageRank"] = list(zip(*pr_cents10))[0]
centralities

# agree on top 4 airports, then betweenness places SNA one above all the others and ranks SJC lower
# overall betweenness diverges the most from consenus
# Out:
#   eigenvector betweenness closeness PageRank
# 0         SFO         LAX       SFO      SFO
# 1         LAX         SFO       LAX      LAX
# 2         SAN         SAN       SAN      SAN
# 3         SMF         SMF       SMF      SMF
# 4         SNA         OAK       SNA      OAK
# 5         OAK         SJC       SJC      SNA
# 6         SJC         ONT       PHX      SJC
# 7         PHX         BUR       DEN      BUR
# 8         DEN         SEA       BUR      ONT
# 9         ONT         PDX       ONT      PHX

# %%
print("Eigenvector centralities")
print(tabulate(eig_ranks10))
print("PageRank centralities")
print(tabulate(pr_cents10))
print("Closeness centralities")
print(tabulate(close_cents10))
print("Betweenness centralities")
print(tabulate(betw_cents10))
# Out:
# Eigenvector centralities
# ---  ---------
# SFO  0.060795
# LAX  0.0558182
# SAN  0.0356594
# SMF  0.0296511
# SNA  0.0279901
# OAK  0.0265384
# SJC  0.0265252
# PHX  0.023522
# DEN  0.0218908
# ONT  0.0215426
# ---  ---------
# PageRank centralities
# ---  ---------
# SFO  0.141081
# LAX  0.120505
# SAN  0.0549773
# SMF  0.0335643
# OAK  0.0290349
# SNA  0.0261997
# SJC  0.0255462
# BUR  0.0221154
# ONT  0.0219357
# PHX  0.0166591
# ---  ---------
# Closeness centralities
# ---  --------
# SFO  0.821429
# LAX  0.807018
# SAN  0.643357
# SMF  0.593548
# SNA  0.578616
# SJC  0.571429
# PHX  0.564417
# DEN  0.557576
# BUR  0.557576
# ONT  0.557576
# ---  --------
# Betweenness centralities
# ---  ---------
# LAX  3435.71
# SFO  2863.75
# SAN   693.84
# SMF   395.371
# OAK   300.445
# SJC   291.658
# ONT   165.52
# BUR   141.136
# SEA    94.4968
# PDX    86.8512
# ---  ---------

# %%
# visualise - use only when using sample of data
m1 # use this instead
# Out:
# <style>
#     text.label_rcHaVrrm {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_rcHaVrrm line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_rcHaVrrm circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="rcHaVrrm">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='rcHaVrrm_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"rcHaVrrm"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "SAN", "target": "BOI", "color": "#999999", "width": 0.5, "weight": 0.6025641025641025}, {"source": "FLL", "target": "SJC", "color": "#999999", "width": 0.5, "weight": 0.02109704641350211}, {"source": "BLI", "target": "OAK", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "ONT", "target": "SMF", "color": "#999999", "width": 0.5, "weight": 0.8644200626959248}, {"source": "LGB", "target": "SAT", "color": "#999999", "width": 0.5, "weight": 0.47368421052631576}, {"source": "OAK", "target": "ABQ", "color": "#999999", "width": 0.5, "weight": 0.9781818181818182}, {"source": "LAX", "target": "MMH", "color": "#999999", "width": 0.5, "weight": 0.9565217391304348}, {"source": "LAX", "target": "BWI", "color": "#999999", "width": 0.5, "weight": 0.9895287958115183}, {"source": "SJC", "target": "IND", "color": "#999999", "width": 0.5, "weight": 0.2}, {"source": "LAX", "target": "BNA", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "ORD", "target": "SAN", "color": "#999999", "width": 0.5, "weight": 0.891844997108155}, {"source": "SMF", "target": "MHT", "color": "#999999", "width": 0.5, "weight": 0.14285714285714285}, {"source": "SFO", "target": "FLL", "color": "#999999", "width": 0.5, "weight": 0.9592123769338959}, {"source": "IAD", "target": "OAK", "color": "#999999", "width": 0.5, "weight": 0.42857142857142855}, {"source": "CMH", "target": "BUR", "color": "#999999", "width": 0.5, "weight": 0.75}, {"source": "MCI", "target": "SNA", "color": "#999999", "width": 0.5, "weight": 0.03324808184143223}, {"source": "LAX", "target": "DAL", "color": "#999999", "width": 0.5, "weight": 0.4663143989431968}, {"source": "DAL", "target": "LAX", "color": "#999999", "width": 0.5, "weight": 0.4583883751651255}, {"source": "MIA", "target": "LAX", "color": "#999999", "width": 0.5, "weight": 0.7777777777777778}, {"source": "LAX", "target": "SUN", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "STL", "target": "SMF", "color": "#999999", "width": 0.5, "weight": 0.08571428571428572}, {"source": "SMF", "target": "PHX", "color": "#999999", "width": 0.5, "weight": 0.056818181818181816}, {"source": "SAN", "target": "ISP", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "ISP", "target": "SAN", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "DEN", "target": "OAK", "color": "#999999", "width": 0.5, "weight": 0.3361664712778429}, {"source": "OAK", "target": "DEN", "color": "#999999", "width": 0.5, "weight": 0.3364595545134818}, {"source": "MSP", "target": "SFO", "color": "#999999", "width": 0.5, "weight": 0.007776049766718507}, {"source": "SFO", "target": "PHL", "color": "#999999", "width": 0.5, "weight": 0.35135135135135137}, {"source": "MSY", "target": "LAX", "color": "#999999", "width": 0.5, "weight": 0.8243243243243243}, {"source": "LAX", "target": "JFK", "color": "#999999", "width": 0.5, "weight": 0.23636363636363636}, {"source": "LAX", "target": "SFO", "color": "#999999", "width": 0.5, "weight": 0.022488755622188907}, {"source": "SFO", "target": "DTW", "color": "#999999", "width": 0.5, "weight": 0.025252525252525252}, {"source": "LGB", "target": "SLC", "color": "#999999", "width": 0.5, "weight": 0.02857142857142857}, {"source": "SLC", "target": "SJC", "color": "#999999", "width": 0.5, "weight": 0.001314060446780552}, {"source": "PSP", "target": "SMF", "color": "#999999", "width": 0.5, "weight": 0.22134387351778656}, {"source": "SMF", "target": "PSP", "color": "#999999", "width": 0.5, "weight": 0.17391304347826086}, {"source": "SFO", "target": "SAN", "color": "#999999", "width": 0.5, "weight": 0.00431203449627597}, {"source": "FLL", "target": "SFO", "color": "#999999", "width": 0.5, "weight": 0.005625879043600563}, {"source": "SFO", "target": "DEN", "color": "#999999", "width": 0.5, "weight": 0.010119940029985007}, {"source": "IAH", "target": "SAN", "color": "#999999", "width": 0.5, "weight": 0.31746031746031744}, {"source": "SAN", "target": "CLT", "color": "#99999 ...

# %% [markdown]
# ## Higher-order network
# So pathpy actually has multi-order models and memory networks - I just want to explore memory networks first.
# ### Useful functions: <br>
#     pp.HigherOrderNetwork(paths,k=order)
#     pp.higher_order_network. +
#     adjacency_matrix(self, include_subpaths=True, weighted=True, transposed=False)
#     laplacian_matrix(self, include_subpaths=True)
#     summary(self)
#     transition_matrix(self, include_subpaths=True)
#     ecount(self)
#     ncount(self)
#     from_paths(paths)
#     leading_eigenvector(A, normalized=True, lanczos_vecs=None, maxiter=None)

# %%
m2 = pp.HigherOrderNetwork(flight_paths,k=2)
m2
# network clearly has disconnected edges
# Out:
# <style>
#     text.label_BrgueiQW {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_BrgueiQW line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_BrgueiQW circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="BrgueiQW">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='BrgueiQW_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"BrgueiQW"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "LAX,DAL", "target": "DAL,LAX", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "MIA,LAX", "target": "LAX,SUN", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "STL,SMF", "target": "SMF,PHX", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "SAN,ISP", "target": "ISP,SAN", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "DEN,OAK", "target": "OAK,DEN", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "MSP,SFO", "target": "SFO,PHL", "color": "#999999", "width": 0.5, "weight": 0.4}, {"source": "MSY,LAX", "target": "LAX,JFK", "color": "#999999", "width": 0.5, "weight": 0.07407407407407407}, {"source": "LAX,SFO", "target": "SFO,DTW", "color": "#999999", "width": 0.5, "weight": 0.8}, {"source": "LGB,SLC", "target": "SLC,SJC", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "PSP,SMF", "target": "SMF,PSP", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "MSP,SFO", "target": "SFO,SAN", "color": "#999999", "width": 0.5, "weight": 0.6}, {"source": "FLL,SFO", "target": "SFO,DEN", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "IAH,SAN", "target": "SAN,CLT", "color": "#999999", "width": 0.5, "weight": 0.9714285714285714}, {"source": "LAS,ONT", "target": "ONT,TUL", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "SAN,SFO", "target": "SFO,ACV", "color": "#999999", "width": 0.5, "weight": 0.8461538461538461}, {"source": "DEN,SMF", "target": "SMF,ONT", "color": "#999999", "width": 0.5, "weight": 0.5714285714285714}, {"source": "ELP,SFO", "target": "SFO,ELP", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "DFW,LAX", "target": "LAX,DTW", "color": "#999999", "width": 0.5, "weight": 0.4444444444444444}, {"source": "TUS,SFO", "target": "SFO,ATL", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "DEN,LAX", "target": "LAX,SBA", "color": "#999999", "width": 0.5, "weight": 0.7391304347826086}, {"source": "ATL,SAN", "target": "SAN,PHX", "color": "#999999", "width": 0.5, "weight": 0.975}, {"source": "DSM,SMF", "target": "SMF,DFW", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "PHX,SAN", "target": "SAN,MSY", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "SEA,SFO", "target": "SFO,BUR", "color": "#999999", "width": 0.5, "weight": 0.5882352941176471}, {"source": "SMF,LAX", "target": "LAX,IAD", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "PSP,SEA", "target": "SEA,LAX", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "BUR,ELP", "target": "ELP,LAX", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "MMH,SFO", "target": "SFO,SAN", "color": "#999999", "width": 0.5, "weight": 0.2}, {"source": "MIA,LAX", "target": "LAX,SBA", "color": "#999999", "width": 0.5, "weight": 0.6428571428571429}, {"source": "SJC,DEN", "target": "DEN,SNA", "color": "#999999", "width": 0.5, "weight": 0.2}, {"source": "BHM,LAX", "target": "LAX,HOU", "color": "#999999", "width": 0.5, "weight": 0.4}, {"source": "SFO,LIH", "target": "LIH,LAX", "color": "#999999", "width": 0.5, "weight": 0.8}, {"source": "SMF,BUR", "target": "BUR,PHX", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "AUS,LGB", "target": "LGB,JFK", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "IAD,LAX", "target": "LAX,SBP", "color": "#999999", "width": 0.5, "weight": 0.9649122807017544}, {"source": "SLC,OAK", "target": "OAK,DFW", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "IAD,LAX", "target": "LAX,OGG", "color": "#999999", "width": 0.5, "weight": 0.4358974358974359}, {"source": "FAT,LAX", "target": "LAX,ABQ", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "LAX,SFO", "target": "SFO,SLC", "color": "#999999", "width": 0.5, "weight": 0.75}, {"source": "DCA,ONT", "target": "ONT,PHX", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "ONT,SFO", "target": "SFO,BWI", "color": "#999999", "widt ...

# %%
# network statistics
print('M2 Network Statistics:')
print("number of nodes: {} (i.e. the number of edges in M1 network)".format(m2.ncount()))
print("number of edges: {}".format(m2.ecount()))
#print("total edge weight: {}".format(m1.transition_matrix())) # not what I expected it to do

print("average clustering coefficient: {}".format(pp.algorithms.statistics.avg_clustering_coefficient(m1)))
print("network diameter: {}".format(pp.algorithms.shortest_paths.diameter(m1)))
# Out:
# M2 Network Statistics:
# number of nodes: 473 (i.e. the number of edges in M1 network)
# number of edges: 630
# average clustering coefficient: 0.44705890333102327
# network diameter: inf

# %%
A2 = m2.adjacency_matrix()
v1 = m2.leading_eigenvector(A2)

# %% [markdown]
# ## Multi-order models

# %% [markdown]
#     help(pp.MultiOrderModel)
# `estimate_order` estimates the optimal **maximum** order of the hierarchical model. `layer_likelihood` calculates the likelhood of the **first** l layers of a multi-order network model. Likelihood calculates the likelihood of the whole model. Try `test_network_hypothesis(self, paths, method='AIC')` to see if it's a network, doesn't consider nested models.

# %%
m1 = pp.MultiOrderModel(flight_paths, max_order=1) 
m2 = pp.MultiOrderModel(flight_paths, max_order=2)
m3 = pp.MultiOrderModel(flight_paths, max_order=3)
# Out:
# 2021-04-01 20:48:31 [Severity.INFO]	Generating 0-th order layer ...
# 2021-04-01 20:48:31 [Severity.INFO]	Generating 1-th order layer ...
# 2021-04-01 20:48:31 [Severity.INFO]	finished.
# 2021-04-01 20:48:31 [Severity.INFO]	Generating 0-th order layer ...
# 2021-04-01 20:48:31 [Severity.INFO]	Generating 1-th order layer ...
# 2021-04-01 20:48:31 [Severity.INFO]	Generating 2-th order layer ...
# 2021-04-01 20:48:33 [Severity.INFO]	finished.
# 2021-04-01 20:48:33 [Severity.INFO]	Generating 0-th order layer ...
# 2021-04-01 20:48:33 [Severity.INFO]	Generating 1-th order layer ...
# 2021-04-01 20:48:33 [Severity.INFO]	Generating 2-th order layer ...
# 2021-04-01 20:48:34 [Severity.INFO]	Generating 3-th order layer ...
# 2021-04-01 20:48:36 [Severity.INFO]	finished.

# %%
print(m1.summary)
print(m2.summary)
print(m3.summary)
# Out:
# <bound method MultiOrderModel.summary of <pathpy.classes.multi_order_model.MultiOrderModel object at 0x166f85850>>
# <bound method MultiOrderModel.summary of <pathpy.classes.multi_order_model.MultiOrderModel object at 0x165b036d0>>
# <bound method MultiOrderModel.summary of <pathpy.classes.multi_order_model.MultiOrderModel object at 0x105251ac0>>

# %%
# Calculates the likelihood of a multi-order network model up to a maximum order max_order based on all path statistics
print('Likelihood = ', m1.likelihood(flight_paths, log=False))
print('Log-likelihood = ', m1.likelihood(flight_paths, log=True))
# Out:
# /usr/local/lib/python3.9/site-packages/pathpy/classes/multi_order_model.py:326: RuntimeWarning: underflow encountered in exp
#   return likelihood if log else np.exp(likelihood)
# Likelihood =  0.0
# Log-likelihood =  -12222217.04195787

# %%
print('Likelihood = ', m2.likelihood(flight_paths, log=False))
print('Log-likelihood = ', m2.likelihood(flight_paths, log=True))
# Out:
# Likelihood =  0.0
# Log-likelihood =  -10417727.35236143

# %%
print('Optimal maximum order = ', m2.estimate_order(flight_paths))
# Optimal order is at least 2, but may be higher.Try to increase `stop_at_order`
# Out:
# 2021-04-01 20:49:36 [Severity.INFO]	Likelihood ratio test for K_opt = 2, x = 3608979.3791928813
# 2021-04-01 20:49:36 [Severity.INFO]	Likelihood ratio test, d_1-d_0 = 106829
# 2021-04-01 20:49:36 [Severity.INFO]	Likelihood ratio test, p = 0.0
# 2021-04-01 20:49:36 [Severity.WARNING]	Optimal order is at least 2, but may be higher.Try to increase `stop_at_order`
# Optimal maximum order =  2

# %%
print('Optimal maximum order = ', m3.estimate_order(flight_paths))
# Optimal order is at 2
# Out:
# 2021-04-01 20:49:42 [Severity.INFO]	Likelihood ratio test for K_opt = 2, x = 3608979.3791928813
# 2021-04-01 20:49:42 [Severity.INFO]	Likelihood ratio test, d_1-d_0 = 106829
# 2021-04-01 20:49:42 [Severity.INFO]	Likelihood ratio test, p = 0.0
# 2021-04-01 20:49:49 [Severity.INFO]	Likelihood ratio test for K_opt = 3, x = 385091.24200374633
# 2021-04-01 20:49:49 [Severity.INFO]	Likelihood ratio test, d_1-d_0 = 2616772
# 2021-04-01 20:49:49 [Severity.INFO]	Likelihood ratio test, p = 1.0
# Optimal maximum order =  2

# %% [markdown]
# # Comparing memory network with time-aggregated network
# **Basics:** same number of nodes? edges? <br>
#
# **Centrality measures:** what nodes are identified as most important in each model? <br>
#
# | Memory model | Time-aggregated model |
# | :----------- | :-------------------- |
# |  | PageRank |
# |  | eigenvector |
# |  | betweenness|
#
# **Clustering:** How do clusters differ? How to compare clustering performance? <br>
# **Graph distances** Are there ways of comparing?
#
# **Predictive performance?:**
# Look at conditional entropy
